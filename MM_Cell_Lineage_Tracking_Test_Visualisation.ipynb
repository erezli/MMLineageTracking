# %% [markdown]
# # Lineage Tracking for Cells in the Mother Machine

# %%
from LineageTrack.lineage_tracker import LineageTrack
from LineageTrack.visualiser import Visualiser
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image, display, HTML

### comment out ###
from jupyterthemes import jtplot
jtplot.style(theme='oceans16')

# %%
# directory = ".\\example\\csv"
# exp = LineageTrack.from_path(directory)

# %%
# trench_list = [i for i in range(10)]
# m = exp.get_mother_cell_growth(trench_list, plot=False)
# mcell1, idx1 = exp.find_division(1, plot=False)
# mcell2, idx2 = exp.find_division(2, plot=False)
# mcell3, idx3 = exp.find_division(3, plot=False)
# mcell4, idx4 = exp.find_division(4, plot=False)
# mcell5, idx5 = exp.find_division(5, plot=False)
# exp.collect_model_para(mcell1, idx1[:], plot=False)
# exp.collect_model_para(mcell2, idx2[:], plot=False)
# exp.collect_model_para(mcell3, idx3[:], plot=False)
# exp.collect_model_para(mcell4, idx4[:-1], plot=False)
# exp.collect_model_para(mcell5, idx5[:], plot=False)
# exp.update_model_para(model="unif")

# %%
# exp.track_trenches([1], threshold=300, max_dpf=3, mode="SeqMatch", p_sp=0, special_reporter=None, show_details=False, save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\csv\\", ret_df=False)

# %%
path1 = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\csv\\track_TR_1.csv"
path2 = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\csv\\lysis_TR_1.csv"
vis = Visualiser.from_path("000", path1, path2)

mask_dir = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\tr1_masks\\"
template_mask = ['xy', '_mCherry_TR', '_T', '-_epoch-20_prob-99.png']

# %%
# cells = vis.track_df.loc[(vis.track_df["trench_id"] == 1) &
#                                               (vis.track_df["time_(mins)"] == 3)].copy()
# print(cells)

# %%
vis.label_images(mask_dir, mode="landscape-line", save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_masks_long\\", template=template_mask)

directory = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_masks_long\\"
files = [f for f in os.listdir(directory)if os.path.isfile(os.path.join(directory, f))]
display(Image(directory+files[0], unconfined=True))
# Out:
# saved as F:\Cambridge\MENG\UROP 2022\Data\MMLT\temp_results\landscape_masks_long\\landscape_line_xy000_mCherry_TR1_T-_epoch-20_prob-99.png

# %%
vis.label_images(mask_dir, mode="barcode", 
                 save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\barcoded_masks_long\\", 
                 template=template_mask)

# %%
vis.get_labelled_image("F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\barcoded_masks_long\\",
                       frames=[0, 1, 2, 3, 4], trench=1, pre="barcoded_", 
                       template=template_mask, template_mode="exp")

# %%
vis.label_images(mask_dir, mode="landscape-gray-scale", 
                 save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_gray_test\\", 
                 template=template_mask, show_other=False, for_frames=None)

directory = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_gray_test\\"
files = [f for f in os.listdir(directory)if os.path.isfile(os.path.join(directory, f))]
display(Image(directory+files[0], unconfined=True))
# Out:
# saved as F:\Cambridge\MENG\UROP 2022\Data\MMLT\temp_results\landscape_gray_test\\landscape_gray_xy000_mCherry_TR1_T-_epoch-20_prob-99.png

# %%
vis.label_images(mask_dir, mode="landscape-gray-scale", 
                 save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_gray_test\\", 
                 template=template_mask, show_other=True, for_frames=(0, 5))
directory = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\landscape_gray_test\\"
files = [f for f in os.listdir(directory)if os.path.isfile(os.path.join(directory, f))]
display(Image(directory+files[1], unconfined=True))
# Out:
# saved as F:\Cambridge\MENG\UROP 2022\Data\MMLT\temp_results\landscape_gray_test\\landscape_gray_xy000_mCherry_TR1_T0-5-_epoch-20_prob-99.png

# %%
vis.label_images(mask_dir, mode="generation-by-poles", save_dir="F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\poles_masks_long\\", template=template_mask)
directory = "F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\poles_masks_long\\"
files = [f for f in os.listdir(directory)if os.path.isfile(os.path.join(directory, f))]

frames = 5
fig, ax = plt.subplots(1, frames, figsize=(100, 100))
ax_flat = ax.flatten()
for i in range(frames):
    img = mpimg.imread(directory + files[i])
    ax_flat[i].imshow(img)
    ax_flat[i].set_ylim(300)

# %%
vis.get_labelled_image("F:\\Cambridge\\MENG\\UROP 2022\\Data\\MMLT\\temp_results\\poles_masks_long\\",
                       frames=[9, 10, 11, 12, 13, 14], trench=1, pre="poles_", 
                       template=template_mask, template_mode="exp")
